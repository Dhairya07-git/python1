# %% [markdown]
# ## Simple if statement
# - if condition:
# (statements)
#
# ## If-else statement
# - if condition:
# (statement-1)
# else
# (statement-2)
#
# ## If-elif-else statement
# - if condition-1:
# (statement-1)
# elif condtion-2:
# (statement-2)
# .
# .
# .
# else
# (statement-n)
#
# ## Nested if
# - if condition-1:
# if condition-2:
# (statement-1)
# else
# (statement-2)
